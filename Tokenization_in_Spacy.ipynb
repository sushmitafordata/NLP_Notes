# %% [markdown]
# ![Screenshot 2023-06-29 at 8.06.13 PM.png](data:image/png;base64,...)

# %% [markdown]
# - Tokenization is not just done using '.' or spaces.
# - We need to use specific rules for it.

# %%
import spacy
#https://spacy.io/usage/models

# %% [markdown]
# #Create blank language object and tokenize words in a sentence

# %%
# creating language object

nlp =spacy.blank("en")

# providing the document

doc =nlp("Dr.Strange loves pav bhaaji of mumbai as it costs only $25 per plate")

#word tokenization
for token in doc:
  print(token)
# Out:
# Dr.
# Strange
# loves
# pav
# bhaaji
# of
# mumbai
# as
# it
# costs
# only
# $
# 25
# per
# plate

# %%
doc[1]
# Out:
# Strange

# %% [markdown]
# ![Screenshot 2023-06-30 at 10.55.09 AM.png](data:image/png;base64,...)

# %% [markdown]
# - spacy gives you an tokenizer to token the words

# %% [markdown]
# #Using index to grab tokens

# %%
doc= nlp("Let's go to N.Y.!")

for token in doc:
  print(token)
# Out:
# Let
# 's
# go
# to
# N.Y.
# !

# %%
# object of english language
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
type(token)
# Out:
# spacy.tokens.token.Token

# %% [markdown]
# #Span Object

# %%
span =doc[0:5]
span
# Out:
# Let's go to N.Y.

# %%
type(span)
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# # Token Attributes

# %%
doc = nlp("Tony gave $2 to Peter.")

# %%
token0=doc[0]
token0
# Out:
# Tony

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
# ...

# %%
token1=doc[1]
token1
# Out:
# gave

# %%
#gives you the list of all functions associated with that particular class
dir(doc)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_bulk_merge',
#  '_context',
#  '_get_array_attrs',
#  '_realloc',
#  '_vector',
#  '_vector_norm',
#  'cats',
#  'char_span',
#  'copy',
#  'count_by',
#  'doc',
#  'ents',
#  'extend_tensor',
#  'from_array',
#  'from_bytes',
#  'from_dict',
#  'from_disk',
#  'from_docs',
#  'from_json',
#  'get_extension',
#  'get_lca_matrix',
#  'has_annotation',
#  'has_extension',
#  'has_unknown_spaces',
#  'has_vector',
#  'is_nered',
#  'is_parsed',
#  'is_sentenced',
#  'is_tagged',
#  'lang',
# ...

# %%
token3=doc[2]
token3
# Out:
# $

# %%
#using one of the functions to check wheather it's an currency or not
token3.is_currency
# Out:
# True

# %%
# Printing the attributes of each token using for loop and token.i
for token in doc:
    print(token, "==>",
          "index: ",token.i,
          "is_alpha:", token.is_alpha,
          "is_punct:", token.is_punct,
          "like_num:", token.like_num,
          "is_currency:", token.is_currency,
         )
# Out:
# Tony ==> index:  0 is_alpha: True is_punct: False like_num: False is_currency: False
# gave ==> index:  1 is_alpha: True is_punct: False like_num: False is_currency: False
# $ ==> index:  2 is_alpha: False is_punct: False like_num: False is_currency: True
# 2 ==> index:  3 is_alpha: False is_punct: False like_num: True is_currency: False
# to ==> index:  4 is_alpha: True is_punct: False like_num: False is_currency: False
# Peter ==> index:  5 is_alpha: True is_punct: False like_num: False is_currency: False
# . ==> index:  6 is_alpha: False is_punct: True like_num: False is_currency: False

# %%
with open("/content/drive/MyDrive/CodeBasics/NLP/students.txt") as f:
  text=f.readlines()
text
#here text is an array of all the lines in the text file
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com \n',
#  'Joe      1 May, 1997    joe@root.com\n',
#  '\n',
#  '\n',
#  '\n']

# %%
#We will use delimiter to join all the arrays to find a single sentence

text=' '.join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com \n Joe      1 May, 1997    joe@root.com\n \n \n \n'

# %%
#Printing the emails
doc=nlp(text)
emails=[]
for token in doc:
  if token.like_email:
    emails.append(token.text)
emails
# Out:
# ['virat@kohli.com',
#  'maria@sharapova.com',
#  'serena@williams.com',
#  'joe@root.com']

# %% [markdown]
# #Support in other languages

# %% [markdown]
# Spacy support many language models. Some of them do not support pipelines though! https://spacy.io/usage/models#languages

# %%
nlp = spacy.blank("hi")
doc = nlp("भैया जी! 5000 ₹ उधार थे वो वापस देदो")
for token in doc:
    print(token, token.is_currency)
# Out:
# भैया False
# जी False
# ! False
# 5000 False
# ₹ True
# उधार False
# थे False
# वो False
# वापस False
# देदो False

# %% [markdown]
# #Customizing tokenizer

# %%
doc= nlp("gimme double cheese extra large healthy pizza")

tokens =[token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %% [markdown]
# - 'Gimme' is made up of two words.
# - So let's say we want to split gimme in two parts whenever it is in the corpus.

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"},
])
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %% [markdown]
# #Sentence Tokenization or Segmentation

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-220059dad4ce> in <cell line: 2>()
#       1 doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# /usr/local/lib/python3.10/dist-packages/spacy/tokens/doc.pyx in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %% [markdown]
# - We need to set the pipeline to tokenize the sentence

# %%
nlp.pipeline
# Out:
# []

# %%
nlp.add_pipe('sentencizer')

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr.
# Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi

# %% [markdown]
# #Spacy Tokenizer Exercise Solution

# %% [markdown]
# Collecting dataset websites from a book paragraph
#
# https://greenteapress.com/thinkstats2/thinkstats2.pdf

# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

# %%
doc = nlp(text)
data_websites = [token.text for token in doc if token.like_url ]
data_websites
# Out:
# ['http://www.data.gov/',
#  'http://www.science',
#  'http://data.gov.uk/.',
#  'http://www3.norc.org/gss+website/',
#  'http://www.europeansocialsurvey.org/.']

# %% [markdown]
# - Figure out all transactions from this text with amount and currency

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"
doc = nlp(transactions)
for token in doc:
    if token.like_num and doc[token.i+1].is_currency:
        print(token.text, doc[token.i+1].text)
# Out:
# 500 €
